# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error , r2_score

# %%
BostonHousing= pd.read_csv('Boston.csv')

# %%
BostonHousing
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
Y=BostonHousing.medv 
Y

# THIS IS BECAUSE LAST COLUMN CORRESPONDS TO ACTUAL COST
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
X= BostonHousing.drop(['medv'] , axis=1)
X

# X MATRIX BEING BUILT UP
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat
# ...

# %%
X_train,X_test,Y_train,Y_test= train_test_split( X,Y,test_size=0.2 )
X_train.shape , Y_train.shape , X_test.shape , Y_test.shape
# Out:
# ((404, 14), (404,), (102, 14), (102,))

# %%
model=linear_model.LinearRegression()

# %%
model.fit(X_train , Y_train )

# MODEL IS FIT BETWEEN X_TRAIN AND Y_TRAIN
# Out:
# LinearRegression()

# %%
Y_pred= model.predict(X_test)

# PREDICTED VALUES OF THE TEST SET ARE STORED IN Y_PRED

# %%
# NOW THE PREDICTION AND ACCURACY ANALYSIS:-

print( 'Coefficients:- ' , model.coef_ )
print( 'Intercept:- ' , model.intercept_ )
print( 'Mean squared error:- ' ,  mean_squared_error( Y_test , Y_pred )   )
print( 'Coefficient of determination R^2:- ' ,  r2_score(Y_test , Y_pred)  )
# Out:
# Coefficients:-  [-1.38322604e-03 -8.57310586e-02  3.69844864e-02 -1.36224441e-02
#   3.79088106e+00 -1.76258307e+01  4.03857565e+00 -8.20464730e-03
#  -1.36211765e+00  2.58972112e-01 -1.12002389e-02 -9.09919397e-01
#   8.15938017e-03 -4.37069015e-01]
# Intercept:-  34.20013897342802
# Mean squared error:-  29.957069062945596
# Coefficient of determination R^2:-  0.7032680676732277

# %%
BostonHousing.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
#     medv= -1.38*(crim) - 8.57*(zn).........   through our model

# %%
sns.scatterplot(Y_test,Y_pred , marker="+" , alpha=1)
# Out:
# /Users/avikalgoel/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='medv'>
